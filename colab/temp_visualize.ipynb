# %%
import numpy as np
import matplotlib.pyplot as plt

# ===== CONFIG =====
file_path = "jaccard_distance_matrix.npy"  # Change to your file

# Load the .npy file
data = np.load(file_path)[:100, :100]  # Load only a subset for visualization

print(f"Loaded {file_path}")
print(f"Shape: {data.shape}")
print(f"Data type: {data.dtype}")

# Show basic statistics
print(f"Min: {np.nanmin(data)}")
print(f"Max: {np.nanmax(data)}")
print(f"Mean: {np.nanmean(data)}")

# Visualize as a heatmap
plt.imshow(data, cmap="viridis", interpolation="nearest")
plt.colorbar(label="Value")
plt.title(f"Visualization of {file_path}")
plt.show()
# Out:
# Loaded jaccard_distance_matrix.npy
# Shape: (3150, 3150)
# Data type: float32
# Min: 0.0
# Max: 0.32258063554763794
# Mean: 0.0047159334644675255
